# %% [markdown]
# ![imagen](https://cdn.foodbeast.com/content/wp-content/uploads/2012/03/beer-print-01-selectism.jpg)
#
# # Ejercicio pandas estadistica
# Para este ejercicio se ha utilizado [un dataset de un concurso de kaggle](https://www.kaggle.com/nickhould/craft-cans), cuyo reto consiste en predecir el tipo de cerveza en función de sus características (nivel de alcohol, amargura, tamaño...).
#
# # Ejercicio 1
# Importa las librerias que consideres

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# ## Ejercicio 2
# 1. Importa el dataset "datasets_beer.csv"
# 2. Imprime por pantalla los primeros registros.
# 3. ¿Cuáles son sus columnas?
# 4. ¿Qué dimensiones tiene el DataFrame?

# %%
beer = pd.read_csv("C:\\Users\\arica\\Desktop\\Mi primer proyecto\\Alumno\\DSPT_TBS_SVL_0922\\2-Data Analytics\\3-Pandas\\ejercicios\\9-Beers\\data\\datasets_beers.csv")
beer.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
beer.columns
# Out:
# Index(['Unnamed: 0', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id',
#        'ounces'],
#       dtype='object')

# %%
beer.shape
# Out:
# (2410, 8)

# %% [markdown]
# ## Ejercicio 3
# [Elimina la columna "Unnamed: 0"](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
beer.drop("Unnamed: 0", axis=1, inplace=True)

# %% [markdown]
# ## Ejercicio 4
# ¿Cuántas filas y columnas tiene el dataset?

# %%
beer.shape
# Out:
# (2410, 7)

# %%
beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu         1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2405 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 131.9+ KB

# %% [markdown]
# ## Ejercicio 5
# ¿De qué tipo son los datos?

# %%
beer.dtypes
# Out:
# abv           float64
# ibu           float64
# id              int64
# name           object
# style          object
# brewery_id      int64
# ounces        float64
# dtype: object

# %% [markdown]
# ## Ejercicio 6
# Obtén en una nuevo DataFrame un resumen con las principales estadísticas de las columnas numércias: mean, max, count, cuartiles...

# %%
beer_std = pd.DataFrame(beer.describe())

# %%
beer_std
# Out:
#                abv          ibu           id   brewery_id       ounces
# count  2348.000000  1405.000000  2410.000000  2410.000000  2410.000000
# mean      0.059773    42.713167  1431.113278   231.749793    13.592241
# std       0.013542    25.954066   752.459975   157.685604     2.352204
# min       0.001000     4.000000     1.000000     0.000000     8.400000
# 25%       0.050000    21.000000   808.250000    93.000000    12.000000
# 50%       0.056000    35.000000  1453.500000   205.000000    12.000000
# 75%       0.067000    64.000000  2075.750000   366.000000    16.000000
# max       0.128000   138.000000  2692.000000   557.000000    32.000000

# %% [markdown]
# ## Ejercicio 7
# ¿Cuántas birras hay de cada estilo en este dataset? [Investiga en la documentación de Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) si puedes hacer un conteo de valores.

# %%
beer["style"].value_counts()
# Out:
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# American Malt Liquor                1
# Wheat Ale                           1
# Flanders Red Ale                    1
# Kristalweizen                       1
# Low Alcohol Beer                    1
# Name: style, Length: 99, dtype: int64

# %% [markdown]
# ## Ejercicio 8
# 1. Imprime por pantalla los registros del 10 al 20
# 2. De esos registros, imprime por pantalla desde la columna `name` a `ounces`, ambas incluidas
# 3. Quédate con las columnas `abv`, `ibu` y `ounces`, y además quédate sólo con los registros 10 al 20.
# 4. Convierte el resultado del apartado 3 en un array de `numpy`

# %%
#1
beer.iloc[10:21]
# Out:
#       abv   ibu    id                          name                    style  \
# 10  0.072   NaN  2099             Sophomoric Saison   Saison / Farmhouse Ale
# 11  0.073   NaN  2098         Regional Ring Of Fire   Saison / Farmhouse Ale
# 12  0.069   NaN  2097                    Garce Selé   Saison / Farmhouse Ale
# 13  0.085   NaN  1980               Troll Destroyer              Belgian IPA
# 14  0.061  60.0  1979                  Bitter Bitch  American Pale Ale (APA)
# 15  0.060   NaN  2318                   Ginja Ninja                    Cider
# 16  0.060   NaN  2170                 Cherried Away                    Cider
# 17  0.060   NaN  2169                  Rhubarbarian                    Cider
# 18  0.060   NaN  1502                   BrightCider                    Cider
# 19  0.082   NaN  1593   He Said Baltic-Style Porter            Baltic Porter
# 20  0.082   NaN  1592  He Said Belgian-Style Tripel                   Tripel
#
#     brewery_id  ounces
# ...

# %%
#2
beer[["name","style", "brewery_id","ounces"]].iloc[10:21]
# Out:
#                             name                    style  brewery_id  ounces
# 10             Sophomoric Saison   Saison / Farmhouse Ale         177    12.0
# 11         Regional Ring Of Fire   Saison / Farmhouse Ale         177    12.0
# 12                    Garce Selé   Saison / Farmhouse Ale         177    12.0
# 13               Troll Destroyer              Belgian IPA         177    12.0
# 14                  Bitter Bitch  American Pale Ale (APA)         177    12.0
# 15                   Ginja Ninja                    Cider         154    12.0
# 16                 Cherried Away                    Cider         154    12.0
# 17                  Rhubarbarian                    Cider         154    12.0
# 18                   BrightCider                    Cider         154    12.0
# 19   He Said Baltic-Style Porter            Baltic Porter         368    12.0
# 20  He Said Belgian-Style Tripel                   Tripel         368    12.0

# %%
#2
beer.iloc[10:21, 3:7]
# Out:
#                             name                    style  brewery_id  ounces
# 10             Sophomoric Saison   Saison / Farmhouse Ale         177    12.0
# 11         Regional Ring Of Fire   Saison / Farmhouse Ale         177    12.0
# 12                    Garce Selé   Saison / Farmhouse Ale         177    12.0
# 13               Troll Destroyer              Belgian IPA         177    12.0
# 14                  Bitter Bitch  American Pale Ale (APA)         177    12.0
# 15                   Ginja Ninja                    Cider         154    12.0
# 16                 Cherried Away                    Cider         154    12.0
# 17                  Rhubarbarian                    Cider         154    12.0
# 18                   BrightCider                    Cider         154    12.0
# 19   He Said Baltic-Style Porter            Baltic Porter         368    12.0
# 20  He Said Belgian-Style Tripel                   Tripel         368    12.0

# %%
#3
beer[['abv','ibu','ounces']].iloc[10:21]
# Out:
#       abv   ibu  ounces
# 10  0.072   NaN    12.0
# 11  0.073   NaN    12.0
# 12  0.069   NaN    12.0
# 13  0.085   NaN    12.0
# 14  0.061  60.0    12.0
# 15  0.060   NaN    12.0
# 16  0.060   NaN    12.0
# 17  0.060   NaN    12.0
# 18  0.060   NaN    12.0
# 19  0.082   NaN    12.0
# 20  0.082   NaN    12.0

# %%
#4
beer_np = np.array(beer[["abv", "ibu", "ounces"]].iloc[10:21])

# %%
beer_np
# Out:
# array([[ 0.072,    nan, 12.   ],
#        [ 0.073,    nan, 12.   ],
#        [ 0.069,    nan, 12.   ],
#        [ 0.085,    nan, 12.   ],
#        [ 0.061, 60.   , 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ]])

# %% [markdown]
# ## Ejercicio 9
# ¿Cuántas onzas pesan todas las birras del dataset?

# %%
beer["ounces"].sum()
# Out:
# 32757.3

# %%
beer.groupby('style')[['ounces']].mean().sort_values('ounces', ascending=True)#[0:10]
# Out:
#                           ounces
# style
# American Barleywine    10.800000
# Abbey Single Ale       12.000000
# Braggot                12.000000
# English Pale Mild Ale  12.000000
# Euro Pale Lager        12.000000
# ...                          ...
# Belgian IPA            16.222222
# Quadrupel (Quad)       16.800000
# American Wild Ale      17.066667
# Flanders Red Ale       19.200000
# American Malt Liquor   24.000000
#
# [99 rows x 1 columns]

# %% [markdown]
# ## Ejercicio 10
# El amargor de las cervezas se mide por su nivel de IBUs.
# 1. ¿Cuál es el amargor medio de las cervezas?
# 2. ¿El máximo? ¿Y el mínimo?
# 3. ¿Qué cerveza es la que tiene el amargor máximo? ¿Cuál es la de amargor mínimo?

# %%
# beer["ibu"].isnull().values.any()

# %%
# 1 y 2
print("La media es", beer["ibu"].mean())
print("El mínimo es", beer["ibu"].min())
print("El máximo es", beer["ibu"].max())
# Out:
# La media es 42.71316725978647
# El mínimo es 4.0
# El máximo es 138.0

# %%
#3
beer [beer["ibu"] == beer["ibu"].max()]
# Out:
#        abv    ibu   id                       name  \
# 147  0.082  138.0  980  Bitter Bitch Imperial IPA
#
#                               style  brewery_id  ounces
# 147  American Double / Imperial IPA         374    12.0

# %%
#3
beer [beer["ibu"] == beer["ibu"].min()]
# Out:
#        abv  ibu    id                                  name      style  \
# 106  0.056  4.0  1350                       Summer Solstice  Cream Ale
# 112  0.056  4.0   753  Summer Solstice Cerveza Crema (2009)  Cream Ale
# 117  0.056  4.0    77                Summer Solstice (2011)  Cream Ale
#
#      brewery_id  ounces
# 106         171    12.0
# 112         171    12.0
# 117         171    12.0

# %% [markdown]
# ## Ejercicio 11
# No queda muy claro cuánto de dispar, de dispersa, es la medida de IBU. Mediante estadística descriptiva (una o dos métricas, sin gráficas), razona la dispersión de la variable IBU.

# %%
beer[['ibu']].describe()
# Out:
#                ibu
# count  1405.000000
# mean     42.713167
# std      25.954066
# min       4.000000
# 25%      21.000000
# 50%      35.000000
# 75%      64.000000
# max     138.000000

# %%
print(beer['ibu'].var())
# Out:
# 673.6135373259929

# %% [markdown]
# ## Ejercicio 12
# ¿Existe alguna relación lineal entre las variables numéricas del dataset? Intenta pintar este razonmiento mediante un gráfico

# %%
beer.corr()
# Out:
#                  abv       ibu        id  brewery_id    ounces
# abv         1.000000  0.670621  0.042811   -0.098632  0.172529
# ibu         0.670621  1.000000  0.000485   -0.004875  0.054691
# id          0.042811  0.000485  1.000000   -0.504030  0.100843
# brewery_id -0.098632 -0.004875 -0.504030    1.000000 -0.133762
# ounces      0.172529  0.054691  0.100843   -0.133762  1.000000

# %%
sns.heatmap(beer[["abv","ibu", "ounces"]].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Ejercicio 13
# Representa el nivel de alcohol (columna `abv`) en un histograma. ¿Se trata de una distribución simétrica o asimétrica?

# %%
beer.abv.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Ejercicio 14
# Representa mediante un *boxplot* de `seaborn` la variable `abv`

# %%
sns.boxplot(beer[["abv"]])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Ejercicio 15
# 1. ¿Qué estilos son los que tienen en media más alcohol?
# 2. ¿Y los estilos que son en media más amargos?

# %%
#1
beer.groupby("style")[["abv"]].mean().sort_values('abv', ascending=False)
# Out:
#                              abv
# style
# English Barleywine      0.107667
# Quadrupel (Quad)        0.104000
# American Barleywine     0.099000
# American Malt Liquor    0.099000
# Russian Imperial Stout  0.097636
# ...                          ...
# Berliner Weissbier      0.043909
# English Dark Mild Ale   0.041500
# Light Lager             0.040417
# Radler                  0.040333
# Low Alcohol Beer        0.001000
#
# [99 rows x 1 columns]

# %%
#2
beer.groupby("style")[["ibu"]].mean().sort_values('ibu', ascending=False)
# Out:
#                                       ibu
# style
# American Barleywine                 96.00
# American Double / Imperial IPA      93.32
# Russian Imperial Stout              86.50
# American Double / Imperial Pilsner  85.00
# Belgian Strong Dark Ale             72.00
# ...                                   ...
# Kristalweizen                         NaN
# Low Alcohol Beer                      NaN
# Mead                                  NaN
# Rauchbier                             NaN
# Shandy                                NaN
#
# [99 rows x 1 columns]

# %% [markdown]
# ## Ejercicio 16
# Carga el datasets de cervecerias `datasets_breweries.csv`

# %%
df_brew = pd.read_csv('data/datasets_breweries.csv')
df_brew.head()
# Out:
#    Unnamed: 0                       name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %% [markdown]
# ## Ejercicio 17
# 1. Renombra la columna `Unnamed: 0` como `brewery_id`
# 2. Renombra tb la columna `name` por `brewery_name`. ¿Puedes hacer ambos apartados en una sola sentencia?

# %%
df_brew.rename(columns={"Unnamed: 0": "brewery_id", "name" : "brewery_name"}, inplace=True)

# %%
df_brew.head()
# Out:
#    brewery_id               brewery_name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %% [markdown]
# ## Ejercicio 18
# Junta los dos datasets que tienes

# %%
df = pd.merge(beer,df_brew)

# %%
df.head()
# Out:
#      abv  ibu    id                 name                           style  \
# 0  0.050  NaN  1436             Pub Beer             American Pale Lager
# 1  0.066  NaN  2265          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  2264  Rise of the Phoenix                    American IPA
# 3  0.090  NaN  2263             Sinister  American Double / Imperial IPA
# 4  0.075  NaN  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces               brewery_name  city state
# 0         408    12.0  10 Barrel Brewing Company  Bend    OR
# 1         177    12.0        18th Street Brewery  Gary    IN
# 2         177    12.0        18th Street Brewery  Gary    IN
# 3         177    12.0        18th Street Brewery  Gary    IN
# 4         177    12.0        18th Street Brewery  Gary    IN

# %% [markdown]
# ## Ejercicio 19
# 1. ¿Cuántos estados diferentes hay?
# 2. ¿Y ciudades diferentes?
# 3. ¿Cuántas cervecerías hay?

# %%
#1
df.state.nunique()
# Out:
# 51

# %%
df.state.unique()
# Out:
# array([' OR', ' IN', ' CA', ' FL', ' MO', ' WA', ' CO', ' LA', ' KY',
#        ' AK', ' WI', ' OH', ' OK', ' NC', ' MI', ' TX', ' CT', ' AL',
#        ' MA', ' AZ', ' MN', ' ME', ' VA', ' IL', ' TN', ' MT', ' WY',
#        ' NE', ' NY', ' UT', ' NJ', ' PA', ' NV', ' SC', ' GA', ' RI',
#        ' IA', ' AR', ' ID', ' SD', ' DC', ' KS', ' ND', ' VT', ' MD',
#        ' WV', ' HI', ' DE', ' NM', ' MS', ' NH'], dtype=object)

# %%
#2
df.city.nunique()
# Out:
# 384

# %%
df.city.unique()
# Out:
# array(['Bend', 'Gary', 'Corvallis', 'San Francisco', 'St Petersburg',
#        'Saint Louis', 'Columbus', 'Gig Harbor', 'Dunedin', 'Golden',
#        'Abita Springs', 'Louisville', 'Kent', 'Portland', 'Juneau',
#        'Madison', 'Lexington', 'Washougal', 'Boonville', 'Hayward',
#        'Cincinnati', 'Oklahoma City', 'Boone', 'Battle Creek',
#        'Colorado Springs', 'Denton', 'South San Francisco', 'Boulder',
#        'Asheville', 'Bellingham', 'Aspen', 'Astoria', 'Detroit', 'Austin',
#        'Fuquay-Varina', 'Bloomfield', 'Gadsden', 'Yakima', 'San Diego',
#        'Williamsburg', 'Granger', 'Tucson', 'Minneapolis', 'Lewiston',
#        'Virginia Beach', 'Lowell', 'Kalamazoo', 'Roseville', 'Duluth',
#        'South Deerfield', 'Alpine', 'Broomfield', 'Sheffield', 'Holland',
#        'Murphysboro', 'Chattanooga', 'Missoula', 'Odessa',
#        'Vadnais Heights', 'Charlotte', 'Hamilton', 'Indianapolis',
# ...

# %%
#3
df.brewery_name.nunique()
# Out:
# 551

# %%
df.brewery_name.unique()
# Out:
# array(['10 Barrel Brewing Company', '18th Street Brewery',
#        '2 Towns Ciderhouse', '21st Amendment Brewery',
#        '3 Daughters Brewing', '4 Hands Brewing Company',
#        '450 North Brewing Company', '7 Seas Brewing Company',
#        '7venth Sun', 'AC Golden Brewing Company', 'Abita Brewing Company',
#        'Against The Grain Brewery', 'Against the Grain Brewery',
#        'Airways Brewing Company', 'Alameda Brewing',
#        'Alaskan Brewing Company', 'Ale Asylum',
#        "Alltech's Lexington Brewing Company", 'Amnesia Brewing Company',
#        'Anchor Brewing Company', 'Anderson Valley Brewing Company',
#        'Angry Minnow', 'Angry Minnow Brewing Company',
#        'Angry Orchard Cider Company', 'Anthem Brewing Company',
#        'Appalachian Mountain Brewery', 'Arcadia Brewing Company',
#        'Arctic Craft Brewery', 'Armadillo Ale Works',
#        'Armstrong Brewing Company', 'Asher Brewing Company',
# ...

# %% [markdown]
# ## Ejercicio 20
# Agrupa por estado y ciudad, la media, mediana y máximo nivel de alcohol

# %%
df.groupby(["state","city"])["abv"].agg(["min", "max", "mean"])
# Out:
#                     min    max      mean
# state city
#  AK   Anchorage   0.048  0.063  0.054200
#       Juneau      0.053  0.053  0.053000
#       Soldotna    0.050  0.068  0.058500
#       Talkeetna   0.056  0.065  0.059500
#  AL   Birmingham  0.056  0.093  0.065400
# ...                 ...    ...       ...
#  WI   Wilson      0.055  0.055  0.055000
#  WV   Lewisburg   0.057  0.067  0.062000
#  WY   Jackson     0.050  0.068  0.054857
#       Pinedale    0.050  0.072  0.061000
#       Sheridan    0.046  0.070  0.052833
#
# [401 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 21
# ¿Cuáles son las cervezas más amargas que se consumen en Indiana, estado = `IN`?

# %%
# msk = df[df["state"] == "IN"]

# %%
df[df["state"].str.contains("IN")].sort_values(by="ibu", ascending=False)
# Out:
#         abv    ibu    id                          name  \
# 479   0.099  115.0  2471              Hopkick Dropkick
# 2191  0.085  115.0  1449         Overlord Imperial IPA
# 811   0.060  104.0  1610                Half Cycle IPA
# 2062  0.091   91.0   651                          Isis
# 2189  0.120   90.0  2621                          Csar
# ...     ...    ...   ...                           ...
# 2056  0.070    NaN   934                     The Deuce
# 2061  0.080    NaN   660                         Chaka
# 2190  0.055    NaN  1817  Klingon Warnog Roggen Dunkel
# 2277  0.060    NaN  1950                 Dragonfly IPA
# 2329  0.047    NaN   780            T-6 Red Ale (2004)
#
#                                style  brewery_id  ounces  \
# 479   American Double / Imperial IPA          24    12.0
# 2191  American Double / Imperial IPA          17    16.0
# 811                     American IPA          16    16.0
# 2062  American Double / Imperial IPA          25    16.0
# ...

# %% [markdown]
# ## Ejercicio 22
# Obtén una tabla con los principales estadísticos del campo `ibu`,  a nivel ciudad

# %%
df.groupby(["city"])["ibu"].describe()
# Out:
#                 count        mean        std    min     25%    50%     75%  \
# city
# Abingdon          1.0  135.000000        NaN  135.0  135.00  135.0  135.00
# Abita Springs     3.0   27.333333  21.455380   13.0   15.00   17.0   34.50
# Ada               0.0         NaN        NaN    NaN     NaN    NaN     NaN
# Afton             4.0   43.000000  19.899749   22.0   28.00   45.0   60.00
# Airway Heights    0.0         NaN        NaN    NaN     NaN    NaN     NaN
# ...               ...         ...        ...    ...     ...    ...     ...
# Woodinville       4.0   46.750000  18.643587   27.0   39.75   44.0   51.00
# Worcester         1.0   69.000000        NaN   69.0   69.00   69.0   69.00
# Yakima            2.0   54.000000  22.627417   38.0   46.00   54.0   62.00
# Yardley           0.0         NaN        NaN    NaN     NaN    NaN     NaN
# York              4.0   44.250000  22.779742   20.0   35.00   41.0   50.25
#
#                   max
# city
# Abingdon        135.0
# ...

# %% [markdown]
# ## Ejercicio 23
# Consigue en un DataFrame todas las cervezas en cuyas cervecerías el mínimo nivel de `abv` sea de 0.07.

# %%
df.loc[df["abv"] < 0.07, "name"]
# Out:
# 0                   Pub Beer
# 1                Devil's Cup
# 6        Lake Street Express
# 7                    Foreman
# 8                       Jade
#                 ...
# 2405               Belgorado
# 2406           Rail Yard Ale
# 2407         B3K Black Lager
# 2408     Silverback Pale Ale
# 2409    Rail Yard Ale (2009)
# Name: name, Length: 1847, dtype: object

# %%
df_abv = pd.DataFrame(df.loc[df["abv"] < 0.07, "name"])

# %%
df_abv
# Out:
#                       name
# 0                 Pub Beer
# 1              Devil's Cup
# 6      Lake Street Express
# 7                  Foreman
# 8                     Jade
# ...                    ...
# 2405             Belgorado
# 2406         Rail Yard Ale
# 2407       B3K Black Lager
# 2408   Silverback Pale Ale
# 2409  Rail Yard Ale (2009)
#
# [1847 rows x 1 columns]

# %% [markdown]
# ## Ejercicio 24
# Teniendo en cuenta la media de amargor de todas las cervezas, obtén una tabla con las cervezas cuyos estados tengan una media de amargor en cerveza por encima de la media

# %%
df.ibu.mean()
# Out:
# 42.71316725978647

# %%
df_amargo = df.groupby(["state", "name"])[["ibu"]].mean()

# %%
df_amargo[df_amargo["ibu"] > 42.71].sort_values('ibu', ascending=False)
# Out:
#                                          ibu
# state name
#  OR   Bitter Bitch Imperial IPA        138.0
#  VA   Troopers Alley IPA               135.0
#  MA   Dead-Eye DIPA                    130.0
#  OH   Bay of Bengal Double IPA (2014)  126.0
#  VT   Heady Topper                     120.0
# ...                                      ...
#  MN   Jack Pine Savage                  43.0
#  AL   Naked Pig Pale Ale                43.0
#  IL   Night Cat                         43.0
#       Night Cat (2014)                  43.0
#  MA   Imperial Pumpkin Stout            43.0
#
# [552 rows x 1 columns]
