# %% [markdown]
# # Ejercicios de Seaborn

# %%
# !pip install seaborn

# %%
# 1. Importa pandas, pyplot y seaborn
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2. Activa matplotlib de forma estática
# %matplotlib inline

# %%
# 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame
pokemon = pd.read_csv("data/Pokemon.csv", encoding= "utf-8", encoding_errors= "ignore", index_col= "#")
pokemon.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
# 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados
pokemon.head(10)
# Out:
#           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1    Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2      Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3     Venusaur  Grass  Poison    525  80      82       83      100      100
# 4   Charmander   Fire     NaN    309  39      52       43       60       50
# 5   Charmeleon   Fire     NaN    405  58      64       58       80       65
# 6    Charizard   Fire  Flying    534  78      84       78      109       85
# 7     Squirtle  Water     NaN    314  44      48       65       50       64
# 8    Wartortle  Water     NaN    405  59      63       80       65       80
# 9    Blastoise  Water     NaN    530  79      83      100       85      105
# 10    Caterpie    Bug     NaN    195  45      30       35       20       20
#
#     Speed  Stage  Legendary
# #
# 1      45      1      False
# 2      60      2      False
# 3      80      3      False
# 4      65      1      False
# 5      80      2      False
# 6     100      3      False
# 7      43      1      False
# 8      58      2      False
# 9      78      3      False
# 10     45      1      False

# %%
# 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
sns.lmplot(x = "HP", y="Attack", data= pokemon)
plt.xlim(20,100)
# Pasa el DataFrame como argumento del método en el parámetro llamado data
# Out:
# (20.0, 100.0)

# %%
# 6. No queremos ver la línea recta de la regresión lineal.
# prueba a añadir fit_reg a falso
sns.lmplot(x = "HP", y="Attack", data= pokemon, fit_reg=False)
plt.xlim(20,100)
# Out:
# (20.0, 100.0)

# %%
# 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el hue sea el Stage
sns.lmplot(x = "HP", y="Attack", data= pokemon, fit_reg=False, hue='Stage')
plt.xlim(20,100)
# Out:
# (20.0, 100.0)

# %%
# 8. Limita el eje x entre 20 y 100
sns.lmplot(x = "HP", y="Attack", data= pokemon, fit_reg=False, hue='Stage')
plt.xlim(20,100)
# Out:
# (20.0, 100.0)

# %%
# 9. Dibuja un diagrama de cajas con el dataframe
sns.boxplot(pokemon)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=pokemon['Attack']);

# %%
# 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas
poke = pokemon.drop(columns=["Stage", "Legendary"], axis=1)
sns.boxplot(poke)
# Out:
# <AxesSubplot:>

# %%
# 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame
pokemon["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon'], dtype=object)

# %%
# 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'
poke_red = pokemon.loc[pokemon["Type 1"].isin(["Grass", "Fire", "Water"])]

# %%
poke_red
# Out:
#            Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur  Grass    Poison    318   45      49       49       65
# 2       Ivysaur  Grass    Poison    405   60      62       63       80
# 3      Venusaur  Grass    Poison    525   80      82       83      100
# 4    Charmander   Fire       NaN    309   39      52       43       60
# 5    Charmeleon   Fire       NaN    405   58      64       58       80
# 6     Charizard   Fire    Flying    534   78      84       78      109
# 7      Squirtle  Water       NaN    314   44      48       65       50
# 8     Wartortle  Water       NaN    405   59      63       80       65
# 9     Blastoise  Water       NaN    530   79      83      100       85
# 37       Vulpix   Fire       NaN    299   38      41       40       50
# 38    Ninetales   Fire       NaN    505   73      76       75       81
# 43       Oddish  Grass    Poison    320   45      50       55       75
# 44        Gloom  Grass    Poison    395   60      65       70       85
# 45    Vileplume  Grass    Poison    490   75      80       85      110
# 54      Psyduck  Water       NaN    320   50      52       48       65
# 55      Golduck  Water       NaN    500   80      82       78       95
# 58    Growlithe   Fire       NaN    350   55      70       45       70
# 59     Arcanine   Fire       NaN    555   90     110       80      100
# 60      Poliwag  Water       NaN    300   40      50       40       40
# 61    Poliwhirl  Water       NaN    385   65      65       65       50
# 62    Poliwrath  Water  Fighting    510   90      95       95       70
# 69   Bellsprout  Grass    Poison    300   50      75       35       70
# 70   Weepinbell  Grass    Poison    390   65      90       50       85
# 71   Victreebel  Grass    Poison    490   80     105       65      100
# 72    Tentacool  Water    Poison    335   40      40       35       50
# 73   Tentacruel  Water    Poison    515   80      70       65       80
# 77       Ponyta   Fire       NaN    410   50      85       55       65
# 78     Rapidash   Fire       NaN    500   65     100       70       80
# 79     Slowpoke  Water   Psychic    315   90      65       65       40
# 80      Slowbro  Water   Psychic    490   95      75      110      100
# 86         Seel  Water       NaN    325   65      45       55       45
# 87      Dewgong  Water       Ice    475   90      70       80       70
# 90     Shellder  Water       NaN    305   30      65      100       45
# 91     Cloyster  Water       Ice    525   50      95      180       85
# 98       Krabby  Water       NaN    325   30     105       90       25
# 99      Kingler  Water       NaN    475   55     130      115       50
# 102   Exeggcute  Grass   Psychic    325   60      40       80       60
# 103   Exeggutor  Grass   Psychic    520   95      95       85      125
# 114     Tangela  Grass       NaN    435   65      55      115      100
# 116      Horsea  Water       NaN    295   30      40       70       70
# 117      Seadra  Water       NaN    440   55      65       95       95
# 118     Goldeen  Water       NaN    320   45      67       60       35
# 119     Seaking  Water       NaN    450   80      92       65       65
# 120      Staryu  Water       NaN    340   30      45       55       70
# 121     Starmie  Water   Psychic    520   60      75       85      100
# 126      Magmar   Fire       NaN    495   65      95       57      100
# 129    Magikarp  Water       NaN    200   20      10       55       15
# 130    Gyarados  Water    Flying    540   95     125       79       60
# 131      Lapras  Water       Ice    535  130      85       80       85
# 134    Vaporeon  Water       NaN    525  130      65       60      110
# 136     Flareon   Fire       NaN    525   65     130       60       95
# 146     Moltres   Fire    Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# 6         85    100      3      False
# 7         64     43      1      False
# 8         80     58      2      False
# 9        105     78      3      False
# 37        65     65      1      False
# 38       100    100      2      False
# 43        65     30      1      False
# 44        75     40      2      False
# 45        90     50      3      False
# 54        50     55      1      False
# 55        80     85      2      False
# 58        50     60      1      False
# 59        80     95      2      False
# 60        40     90      1      False
# 61        50     90      2      False
# 62        90     70      3      False
# 69        30     40      1      False
# 70        45     55      2      False
# 71        70     70      3      False
# 72       100     70      1      False
# 73       120    100      2      False
# 77        65     90      1      False
# 78        80    105      2      False
# 79        40     15      1      False
# 80        80     30      2      False
# 86        70     45      1      False
# 87        95     70      2      False
# 90        25     40      1      False
# 91        45     70      2      False
# 98        25     50      1      False
# 99        50     75      2      False
# 102       45     40      1      False
# 103       65     55      2      False
# 114       40     60      1      False
# 116       25     60      1      False
# 117       45     85      2      False
# 118       50     63      1      False
# 119       80     68      2      False
# 120       55     85      1      False
# 121       85    115      2      False
# 126       85     93      1      False
# 129       20     80      1      False
# 130      100     81      2      False
# 131       95     60      1      False
# 134       95     65      2      False
# 136      110     65      2      False
# 146       85     90      1       True

# %%
# 13. Usa un estilo 'whitegrid'
sns.set_style("whitegrid")

# %%
# 14. Pinta diagramas de violín con el DataFrame
sns.violinplot(poke)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
sns.violinplot(x='Type 1', y='Attack', data=poke)
plt.xlabel('Tipos de pokemon', fontsize=30);

# %%
# 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'
colores = ["#78C850", "#F08030", "#6890F0"]

# %%
# 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)
plt.figure(figsize=(20,10))
sns.violinplot(x='Type 1', y='Attack', data=poke, palette=colores)
plt.xlabel('Tipos de pokemon', fontsize=30);

# %%
# 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# Para ver esto, usamos el swarmplot.
# Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin
sns.swarmplot(x= 'Type 1', y= 'Attack', data=poke_red);

# %%
# 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. 
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9
# Pon un título con pyplot (como siempre)
sns.violinplot(x= 'Type 1', y= 'Attack', data=poke_red, inner = None)
sns.swarmplot(x= 'Type 1', y= 'Attack', data=poke_red, color='k', alpha=0.9)
plt.title('Pokemons');

# %%
sns.stripplot(poke_red)
# Out:
# <AxesSubplot:>

# %%
# 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas

# Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas
poke_red.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
# 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')
df_melted = poke_red.melt(id_vars=['Name', 'Type 1'], value_vars=['HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed', 'Stage'], var_name='Melted variables')
df_melted
# Out:
#            Name Type 1 Melted variables  value
# 0     Bulbasaur  Grass               HP     45
# 1       Ivysaur  Grass               HP     60
# 2      Venusaur  Grass               HP     80
# 3    Charmander   Fire               HP     39
# 4    Charmeleon   Fire               HP     58
# ..          ...    ...              ...    ...
# 359    Gyarados  Water            Stage      2
# 360      Lapras  Water            Stage      1
# 361    Vaporeon  Water            Stage      2
# 362     Flareon   Fire            Stage      2
# 363     Moltres   Fire            Stage      1
#
# [364 rows x 4 columns]

# %%
df_melted.shape
# Out:
# (364, 4)

# %%
# 21. Pintamos el swarmplot con el melted y entendemos la información
sns.swarmplot(x='Melted variables', y='value', data=df_melted, hue='Type 1');
# Out:
# c:\Users\arica\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 82.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\arica\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 86.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\arica\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 86.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\arica\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 86.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon

# Dodge en inglés es "esquivar", ¿qué diferencia ves?

# Usando plt 
# fija el límite del eje Y entre 0 y 200
# fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %%
plt.figure(figsize=(10,6))

sns.swarmplot(x='Melted variables', y='value', data=df_melted, hue='Type 1', dodge=True, palette=colores);

plt.ylim(0,200)
plt.legend(bbox_to_anchor=(1,1), loc=2)
# Out:
# c:\Users\arica\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 60.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\arica\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 53.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\arica\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 53.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\arica\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 53.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# Lo importante es que Seaborn y Pyplot conviven bien juntos

# %%
# 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
# Pista: las correlaciones se calculan con el método corr()
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)
poke.corr()
# Out:
#             Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# Total    1.000000  0.576591  0.670939  0.508694  0.680745  0.774383  0.506950
# HP       0.576591  1.000000  0.306768  0.119782  0.236649  0.490978 -0.040939
# Attack   0.670939  0.306768  1.000000  0.491965  0.146312  0.369069  0.194701
# Defense  0.508694  0.119782  0.491965  1.000000  0.187569  0.139912 -0.053252
# Sp. Atk  0.680745  0.236649  0.146312  0.187569  1.000000  0.522907  0.411516
# Sp. Def  0.774383  0.490978  0.369069  0.139912  0.522907  1.000000  0.392656
# Speed    0.506950 -0.040939  0.194701 -0.053252  0.411516  0.392656  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(poke.corr(),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True)
# Out:
# <AxesSubplot:>

# %%
# ¿la correlación entre qué valores se encuentra?
# la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías?

# %%
# 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
sns.distplot(poke['Defense']);
# Out:
# C:\Users\arica\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas

# %%
plt.figure(figsize=(7,5))
sns.countplot(x=pokemon["Type 1"])
plt.xticks(rotation=-45, fontsize=10);

# %% [markdown]
# ## OPCIONALES

# %%
# 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# y divide los colores según el Type 2
sns.catplot(x='Type 1', y='Defense', data=pokemon, hue='Type 2', col='Legendary')

plt.xticks(rotation=-45, fontsize=10);

# %%
# 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %%
plt.figure(figsize=(5,5))
sns.jointplot(x = poke['Attack'],y = poke['Defense'],kind="kde");

# %%
# 28. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original

# %%
sns.jointplot(x='Attack', y='Defense', data=pokemon);
